# %%
# %matplotlib inline

import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))
from collections import defaultdict
import math

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import glob
from mpl_toolkits.mplot3d import Axes3D

from sklearn.manifold import TSNE, MDS, Isomap
from sklearn.decomposition import PCA, KernelPCA

import torch
from torch.utils.data import DataLoader

from src.datasets.manifolds import SwissRoll, SCurve, Spheres
from src.evaluation.utils import get_space

#from src.datasets.splitting import split_dataset

torch.manual_seed(42)
np.random.seed(42)

# %%
batch_size = 64
train = True
datasets_ = {'dataset.SwissRoll': SwissRoll(train=train), 'dataset.SCurve': SCurve(train=train),
             'dataset.Spheres': Spheres(train=train)}
experiments = defaultdict(lambda:defaultdict(dict))
for f in sorted(glob.glob('../exp_runs/train_model/dimred_repetitions_cycles/**/run.json', recursive=True)):
    d = os.path.dirname(f)
    dataset, method  = d.split('/')[-2:]
    if method == '1':
        continue
    print(dataset, method)
    path = os.path.join(d, 'model.pth')
    
    dataloader = DataLoader(datasets_[dataset], batch_size=batch_size, shuffle=False,
            pin_memory=True, drop_last=True)
    
    experiments[dataset]['data_space'] = get_space(None, dataloader, mode='data')[0]

    model = torch.load(path)

    #Keep path, model, and latent space in dict:
    experiments[dataset][method]['path'] = path 
    experiments[dataset][method]['model'] = model

    latent, labels = get_space(model, dataloader, mode='latent')

    experiments[dataset][method]['latent'] = latent
    experiments[dataset][method]['labels'] = labels
# Out:
# dataset.SCurve model.TopoRegEdgeSymmetric_rep1
# dataset.SCurve model.TopoRegEdgeSymmetric_rep2
# dataset.SCurve model.TopoRegEdgeSymmetric_rep3
# dataset.SCurve model.TopoRegEdgeSymmetric_rep4
# dataset.SCurve model.TopoRegSorted_rep1
# dataset.SCurve model.TopoRegSorted_rep2
# dataset.SCurve model.TopoRegSorted_rep3
# dataset.SCurve model.TopoRegSorted_rep4
# dataset.SCurve model.VAETopoRegEdgeSymmetric_rep1
# dataset.SCurve model.VAETopoRegEdgeSymmetric_rep2
# dataset.SCurve model.VAETopoRegEdgeSymmetric_rep3
# dataset.SCurve model.VAETopoRegEdgeSymmetric_rep4
# dataset.Spheres model.TopoRegEdgeSymmetric_rep1
# dataset.Spheres model.TopoRegEdgeSymmetric_rep2
# dataset.Spheres model.TopoRegEdgeSymmetric_rep3
# dataset.Spheres model.TopoRegEdgeSymmetric_rep4
# dataset.Spheres model.TopoRegSorted_rep1
# dataset.Spheres model.TopoRegSorted_rep2
# dataset.Spheres model.TopoRegSorted_rep3
# dataset.Spheres model.TopoRegSorted_rep4
# dataset.Spheres model.VAETopoRegEdgeSymmetric_rep1
# dataset.Spheres model.VAETopoRegEdgeSymmetric_rep2
# dataset.Spheres model.VAETopoRegEdgeSymmetric_rep3
# dataset.Spheres model.VAETopoRegEdgeSymmetric_rep4
# dataset.SwissRoll model.TopoRegEdgeSymmetric_rep1
# dataset.SwissRoll model.TopoRegEdgeSymmetric_rep2
# dataset.SwissRoll model.TopoRegEdgeSymmetric_rep3
# dataset.SwissRoll model.TopoRegEdgeSymmetric_rep4
# dataset.SwissRoll model.TopoRegSorted_rep1
# dataset.SwissRoll model.TopoRegSorted_rep2
# dataset.SwissRoll model.TopoRegSorted_rep3
# dataset.SwissRoll model.TopoRegSorted_rep4
# dataset.SwissRoll model.VAETopoRegEdgeSymmetric_rep1
# dataset.SwissRoll model.VAETopoRegEdgeSymmetric_rep2
# dataset.SwissRoll model.VAETopoRegEdgeSymmetric_rep3
# dataset.SwissRoll model.VAETopoRegEdgeSymmetric_rep4

# %%
experiments['dataset.SwissRoll']
# Out:
# defaultdict(dict,
#             {'data_space': array([[ 0.4827889 ,  0.04321421, -0.4088888 ],
#                     [ 0.94560814,  1.2793291 , -1.2214768 ],
#                     [ 0.54826206, -1.6601657 ,  0.56483155],
#                     ...,
#                     [ 0.00661178, -0.71719366, -0.6858088 ],
#                     [-1.1499939 ,  0.41007394,  0.9137181 ],
#                     [ 1.4892452 ,  1.3417665 ,  0.75213724]], dtype=float32),
#              'model.TopoRegEdgeSymmetric_rep1': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.TopoRegEdgeSymmetric_rep1/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.21287334, -0.23026443],
#                      [ 0.29983276, -0.06459936],
#                      [-0.06704683, -0.43473405],
#                      ...,
#                      [ 0.27765405, -0.2770588 ],
#                      [-0.14126575,  0.29410928],
#                      [-0.16199234, -0.03238785]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.TopoRegEdgeSymmetric_rep2': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.TopoRegEdgeSymmetric_rep2/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.42185545, -0.28473344],
#                      [ 0.40208423, -0.09666721],
#                      [ 0.17761546, -0.58777976],
#                      ...,
#                      [ 0.48675182, -0.2466949 ],
#                      [-0.04494942, -0.02090248],
#                      [ 0.1795704 , -0.26041985]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.TopoRegEdgeSymmetric_rep3': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.TopoRegEdgeSymmetric_rep3/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.2626444 ,  0.0222609 ],
#                      [ 0.39588407, -0.3664345 ],
#                      [ 0.05072407,  0.44620097],
#                      ...,
#                      [ 0.2652611 ,  0.1863895 ],
#                      [ 0.22471227,  0.43482226],
#                      [-0.22284503, -0.26102746]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.TopoRegEdgeSymmetric_rep4': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.TopoRegEdgeSymmetric_rep4/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.31893867,  0.10838974],
#                      [ 0.2752447 , -0.06063763],
#                      [ 0.20343637,  0.4334806 ],
#                      ...,
#                      [ 0.36901307,  0.11085989],
#                      [-0.2747999 , -0.15751775],
#                      [-0.04917596,  0.13679613]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.TopoRegSorted_rep1': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.TopoRegSorted_rep1/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.0442053 , -0.17848837],
#                      [ 0.08427304,  0.7691545 ],
#                      [-0.23904043, -0.47044265],
#                      ...,
#                      [ 0.11121362, -0.30994678],
#                      [ 0.06896774,  0.07496199],
#                      [-0.6156617 ,  0.79352695]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.TopoRegSorted_rep2': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.TopoRegSorted_rep2/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.30531073, -0.36885116],
#                      [ 0.29349574, -0.21488272],
#                      [-0.10782945, -0.7212386 ],
#                      ...,
#                      [ 0.50603825, -0.3383539 ],
#                      [-0.21782227, -0.03980365],
#                      [-0.02727656, -0.30606428]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.TopoRegSorted_rep3': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.TopoRegSorted_rep3/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.28240207,  0.39264715],
#                      [ 0.6051863 , -0.57515085],
#                      [-0.09869573,  0.70262396],
#                      ...,
#                      [ 0.35480168,  0.55315924],
#                      [ 0.04793656, -0.02914277],
#                      [ 0.67462087, -0.04034255]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.TopoRegSorted_rep4': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.TopoRegSorted_rep4/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.16037333, -0.01826413],
#                      [ 0.08032793,  0.6303072 ],
#                      [ 0.12744711, -0.3243966 ],
#                      ...,
#                      [ 0.26686904, -0.21628213],
#                      [-0.4345467 , -0.49993098],
#                      [-0.67726344,  0.5364782 ]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.VAETopoRegEdgeSymmetric_rep1': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.VAETopoRegEdgeSymmetric_rep1/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.21287334, -0.23026443],
#                      [ 0.29983276, -0.06459936],
#                      [-0.06704683, -0.43473405],
#                      ...,
#                      [ 0.27765405, -0.2770588 ],
#                      [-0.14126575,  0.29410928],
#                      [-0.16199234, -0.03238785]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.VAETopoRegEdgeSymmetric_rep2': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.VAETopoRegEdgeSymmetric_rep2/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.42185545, -0.28473344],
#                      [ 0.40208423, -0.09666721],
#                      [ 0.17761546, -0.58777976],
#                      ...,
#                      [ 0.48675182, -0.2466949 ],
#                      [-0.04494942, -0.02090248],
#                      [ 0.1795704 , -0.26041985]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.VAETopoRegEdgeSymmetric_rep3': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.VAETopoRegEdgeSymmetric_rep3/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.2626444 ,  0.0222609 ],
#                      [ 0.39588407, -0.3664345 ],
#                      [ 0.05072407,  0.44620097],
#                      ...,
#                      [ 0.2652611 ,  0.1863895 ],
#                      [ 0.22471227,  0.43482226],
#                      [-0.22284503, -0.26102746]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)},
#              'model.VAETopoRegEdgeSymmetric_rep4': {'path': '../exp_runs/train_model/dimred_repetitions_cycles/dataset.SwissRoll/model.VAETopoRegEdgeSymmetric_rep4/model.pth',
#               'model': TopologicallyRegularizedAutoencoder(
#                 (topo_sig): TopologicalSignatureDistance()
#                 (autoencoder): MLPAutoencoder(
#                   (encoder): Sequential(
#                     (0): Linear(in_features=3, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=2, bias=True)
#                   )
#                   (decoder): Sequential(
#                     (0): Linear(in_features=2, out_features=32, bias=True)
#                     (1): ReLU(inplace)
#                     (2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (3): Linear(in_features=32, out_features=32, bias=True)
#                     (4): ReLU(inplace)
#                     (5): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (6): Linear(in_features=32, out_features=3, bias=True)
#                   )
#                   (reconst_error): MSELoss()
#                 )
#               ),
#               'latent': array([[ 0.31893867,  0.10838974],
#                      [ 0.2752447 , -0.06063763],
#                      [ 0.20343637,  0.4334806 ],
#                      ...,
#                      [ 0.36901307,  0.11085989],
#                      [-0.2747999 , -0.15751775],
#                      [-0.04917596,  0.13679613]], dtype=float32),
#               'labels': array([ 5.806348 , 11.768204 ,  6.908541 , ...,  5.118598 ,  8.5444145,
#                      12.99852  ], dtype=float32)}})

# %%
n_samples = 10000

# %%
def plotting(transformed, all_labels, title):
    plt.scatter(transformed[:, 0], transformed[:, 1], c=all_labels, cmap=plt.cm.Spectral, s=2., alpha=0.5)
    plt.title(title)

def plott_all(dataset_name, X,labels, methods, all_Z):
    fig = plt.figure(1)
    n_cols = 3
    n_rows = math.ceil((len(methods) + 1) / n_cols)
    ax = fig.add_subplot(n_rows, n_cols, 1, projection="3d")
    
    #Plot Swiss Roll Data:
    ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels, cmap=plt.cm.Spectral, s=2., alpha=0.5)

    plt.xticks([]), plt.yticks([])
    myfontsize = 18
    dataset_name = dataset_name.split('.')[1]
    plt.title(dataset_name, fontsize=myfontsize)
    ax.set_xlabel('x', fontsize=myfontsize)
    ax.set_ylabel('y', fontsize=myfontsize)
    ax.set_zlabel('z', fontsize=myfontsize)
    fig.set_size_inches(n_cols*4, n_rows*4)
    ax.view_init(15, 290) # rotation of the 3D plot
    # plt.show()
    
    subplot_count = 2
    for method, latent in zip(methods, all_Z):
        #add subplots for latent spaces:
        ax = fig.add_subplot(n_rows, n_cols, subplot_count)
        method = method.split('.')[1]
        plotting(latent, labels, f'{method}')
        subplot_count += 1
 
    # hard-coded:
    #     ax = fig.add_subplot(322)
    #     plotting(all_Z[0], labels, f'2D Latent Space {methods[0]}')

    #     ax = fig.add_subplot(323)
    #     plotting(all_Z[1], labels, f'2D Latent Space {methods[1]}')

    #     ax = fig.add_subplot(324)
    #     plotting(all_Z[2], labels, f'2D Latent Space {methods[2]}')

    #     ax = fig.add_subplot(325)
    #     plotting(all_Z[3], labels, f'2D Latent Space {methods[3]}')

    #     ax = fig.add_subplot(326)
    #     plotting(all_Z[4], labels, f'2D Latent Space {methods[4]}')

# %%
# %matplotlib inline

dataset= 'dataset.SCurve' #'swissroll' #'scurve' #'spheres'
for dataset in experiments.keys():

    X = experiments[dataset]['data_space']
    labels = experiments[dataset]['model.TopoRegSorted_rep1']['labels']

    methods = []
    all_Z = []
    for key, value in experiments[dataset].items():
        if  key.startswith('model'):
            methods.append(key)
            all_Z.append(value['latent'])
    plott_all(dataset, X, labels, methods, all_Z)
    plt.show()
    plt.savefig(f'{dataset}.png', dpi=200)


#Z2 = experiments[dataset][methods[4]]['latent']


# plt.savefig(f'200_epochs_{dataset}_train.png')
